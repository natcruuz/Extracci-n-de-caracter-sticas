# %% [markdown]
# <a href="https://colab.research.google.com/github/natcruuz/Extracci-n-de-caracter-sticas/blob/main/Actividad4_Extraccion_de_Caracteristicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para el análisis de variable categóricas
# %pip install funpymodeling

# %%
#Importamos las librerías pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Cargar desde un archivo .xlsx sin índice
Micro_Retailer = pd.read_excel("microretailer_mit_lift_lab.xlsx")

# %%
#Verificamos información del data frame
Micro_Retailer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB

# %%
#Imprimimos los 5 primeros registros del data frame
Micro_Retailer.head(1)

# %%
#Elegimos las 20 columnas de tipo categórico
#tabnv = Micro_Retailer.iloc[:,[1,3,9,10,11,12,13,14,15,21,22,24,25,30,31,32,34,36,47,48]]
tab = Micro_Retailer.iloc[:,[1,3,9,10,11,12,15,23,24,25,30,32,34,36,47,48,26,27,35,53]]
#tabnv = Micro_Retailer.iloc[:,[13]]
tab.head(1)
# Out:
#               _title           _updated_by 232_type_of_store  \
# 0  November 12, 2022  Salomon Abdala Perez            Tailor
#
#   108_does_the_micro_retailer_has_a_barred_window_  \
# 0                                              yes
#
#   99_does_the_micro_retailer_exhibits_products_outside_  \
# 0                                                 no
#
#   102_does_the_micro_retailer_sells_fresh_products_  \
# 0                                                no
#
#                                    184_store_devices  \
# 0  POS system (i.e. computer + bar code scanner +...
#
#   5_change_store_space_last_year 6_change_employees_average_salary_last_year  \
# 0                      No cambió                                   No cambió
#
#   20_reviews_finances_monthly 19_tax_id 310_burnout 186_internet_connection  \
# 0                         yes       yes          no                     yes
#
#                     189_payment_methods 214_customer_relationship_tools  \
# ...

# %%
#Identificamos los valores nulos
valores_nulos = tab.isnull().sum()
valores_nulos
# Out:
# _title                                                    0
# _updated_by                                               0
# 232_type_of_store                                         0
# 108_does_the_micro_retailer_has_a_barred_window_          0
# 99_does_the_micro_retailer_exhibits_products_outside_     0
# 102_does_the_micro_retailer_sells_fresh_products_         0
# 184_store_devices                                         2
# 5_change_store_space_last_year                           72
# 6_change_employees_average_salary_last_year              86
# 20_reviews_finances_monthly                              63
# 19_tax_id                                                71
# 310_burnout                                              64
# 186_internet_connection                                  63
# 189_payment_methods                                      64
# 214_customer_relationship_tools                          76
# 33_credit_to_customers                                   64
# ...

# %% [markdown]
# **Sustituimos valores nulos**

# %%
#Hacemos una copia de la tabla anterior
tabnv = tab.copy()

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
tabnv["184_store_devices"] = tabnv["184_store_devices"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
tabnv["5_change_store_space_last_year"] = tabnv["5_change_store_space_last_year"].fillna(method="ffill")

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backwardfill ("bfill")
#Filtro por columnas
tabnv["6_change_employees_average_salary_last_year"]=tabnv["6_change_employees_average_salary_last_year"].fillna(method="bfill")

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backwardfill ("bfill")
#Filtro por columnas
tabnv["20_reviews_finances_monthly"]=tabnv["20_reviews_finances_monthly"].fillna(method="bfill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["6_change_employees_average_salary_last_year"] = tabnv["6_change_employees_average_salary_last_year"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["20_reviews_finances_monthly"] = tabnv["20_reviews_finances_monthly"].fillna(method="ffill")

# %%
#Sustituir valores nulos por valores no nulos hacia atrás "forward fill" ("ffill")
#Filtro por columnas
tabnv["19_tax_id"]=tabnv["19_tax_id"].fillna(method="ffill")

# %%
#Sustituir valores nulos por valores no nulos hacia atrás forward fill ("ffill")
#Filtro por columnas
tabnv["310_burnout"]=tabnv["310_burnout"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["186_internet_connection"] = tabnv["186_internet_connection"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["189_payment_methods"] = tabnv["189_payment_methods"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["214_customer_relationship_tools"] = tabnv["214_customer_relationship_tools"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["33_credit_to_customers"] = tabnv["33_credit_to_customers"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["49_inventory_records"] = tabnv["49_inventory_records"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["18_sales_records"] = tabnv["18_sales_records"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["210_sales_channels"] = tabnv["210_sales_channels"].fillna(method="ffill")

# %%
#Sustituir los valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtros por columnas
tabnv["193_sales_planning_tools"] = tabnv["193_sales_planning_tools"].fillna(method="ffill")

# %%
#Corroboramos los valores nulos
valores_nulos = tabnv.isnull().sum()
valores_nulos

# %% [markdown]
# **Análisis univariado**

# %%
#Obtengo un análisis univariado de las variables categóricas
#Primero obtenemos la tabla de frecuencias
freq_tbl(tabnv)

# %% [markdown]
# **Primera columna "_title"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1 = freq_tbl(tabnv["_title"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro1 = table1[table1["frequency"]>1]
filtro1

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro1_index = filtro1.set_index("_title")
filtro1_index
# Out:
#                    frequency  percentage  cumulative_perc
# _title
# November 9, 2022          73    0.426901         0.426901
# November 10, 2022         26    0.152047         0.578947
# November 7, 2022          20    0.116959         0.695906
# November 3, 2022          16    0.093567         0.789474
# November 12, 2022         15    0.087719         0.877193
# November 8, 2022          10    0.058480         0.935673
# November 4, 2022           9    0.052632         0.988304

# %%
#Realizamos el gráfico de barras del dataframe filtrado
filtro1_index.plot(kind = "bar", width = 1, figsize=(10,4))
plt.title("Fecha en la que se realizó la encuesta")
plt.xlabel("Fecha")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Segunda columna "_updated_by"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2 = freq_tbl(tabnv["_updated_by"])
table2

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro2 = table2[table2["frequency"]>1]
filtro2

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro2_index = filtro2.set_index("_updated_by")
filtro2_index
# Out:
#                                    frequency  percentage  cumulative_perc
# _updated_by
# Salomon Abdala Perez                      20    0.116959         0.116959
# Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# José Zapata                               14    0.081871         0.292398
# Emilio Garza                              13    0.076023         0.368421
# Benjamin Barbosa                          13    0.076023         0.444444
# Pedro Contreras                           12    0.070175         0.514620
# Eduardo Zárate                             9    0.052632         0.567251
# Alejandro Matias                           8    0.046784         0.614035
# Harry Hernández                            7    0.040936         0.654971
# Francisco Adán                             7    0.040936         0.695906
# Hiram Jiménez                              6    0.035088         0.730994
# ...

# %%
#realizamos gráfico de dispersión del dataframe filtrado
filtro2_index.plot("frequency", "cumulative_perc", kind = "scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Tercera variable "232_type_of_store"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3 = freq_tbl(tabnv["232_type_of_store"])
table3

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro3 = table3[table3["frequency"]>1]
filtro3

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro3_index = filtro3.set_index("232_type_of_store")
filtro3_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 232_type_of_store
# Grocery store (aka. nanostore)          52    0.304094         0.304094
# Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# Dairy products                          10    0.058480         0.543860
# Cafeteria                                6    0.035088         0.578947
# Butcher shop                             6    0.035088         0.614035
# Produce (fruits & vegetables)            4    0.023392         0.637427
# Handmade products                        2    0.011696         0.649123
# Papelería                                2    0.011696         0.660819
# objetos                                  2    0.011696         0.672515
# Ferretería                               2    0.011696         0.684211

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro3_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%") #esto último se refiere a un decimal
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Cuarta columna "108_does_the_micro_retailer_has_a_barred_window_"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4 = freq_tbl(tabnv["108_does_the_micro_retailer_has_a_barred_window_"])
table4

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro4 = table4[table4["frequency"]>1]
filtro4

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro4_index = filtro4.set_index("108_does_the_micro_retailer_has_a_barred_window_")
filtro4_index
# Out:
#                                                   frequency  percentage  \
# 108_does_the_micro_retailer_has_a_barred_window_
# no                                                      124    0.725146
# yes                                                      47    0.274854
#
#                                                   cumulative_perc
# 108_does_the_micro_retailer_has_a_barred_window_
# no                                                       0.725146
# yes                                                      1.000000

# %%
#Realizamos el gráfico de barras del dataframe filtrado
filtro4_index.plot(kind = "bar", width = 1, figsize=(10,4))
plt.title("La tienda tiene ventanas enrejadas")
plt.xlabel("Tipo de Herramienta")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Quinta columna "99_does_the_micro_retailer_exhibits_products_outside_"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table5 = freq_tbl(tabnv["99_does_the_micro_retailer_exhibits_products_outside_"])
table5

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro5 = table5[table5["frequency"]>1]
filtro5

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro5_index = filtro5.set_index("99_does_the_micro_retailer_exhibits_products_outside_")
filtro5_index
# Out:
#                                                     frequency  percentage  \
# 99_does_the_micro_retailer_exhibits_products_ou...
# no                                                        120    0.701754
# yes                                                        51    0.298246
#
#                                                     cumulative_perc
# 99_does_the_micro_retailer_exhibits_products_ou...
# no                                                         0.701754
# yes                                                        1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro5_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%") #esto último se refiere a un decimal
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Sexta columna "102_does_the_micro_retailer_sells_fresh_products_"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table6 = freq_tbl(tabnv["102_does_the_micro_retailer_sells_fresh_products_"])
table6

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro6 = table6[table6["frequency"]>1]
filtro6

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro6_index = filtro6.set_index("102_does_the_micro_retailer_sells_fresh_products_")
filtro6_index
# Out:
#                                                    frequency  percentage  \
# 102_does_the_micro_retailer_sells_fresh_products_
# no                                                       105    0.614035
# yes                                                       66    0.385965
#
#                                                    cumulative_perc
# 102_does_the_micro_retailer_sells_fresh_products_
# no                                                        0.614035
# yes                                                       1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro6_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%") #esto último se refiere a un decimal
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Séptima columna "184_store_devices"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7 = freq_tbl(tabnv["184_store_devices"])
table7

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro7 = table7[table7["frequency"]>1]
filtro7

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro7_index = filtro7.set_index("184_store_devices")
filtro7_index
# Out:
#                                                     frequency  percentage  \
# 184_store_devices
# Smartphone                                                 53    0.309942
# Analog cash register                                       16    0.093567
# POS system (i.e. computer + bar code scanner + ...          9    0.052632
# POS system (i.e. computer + bar code scanner + ...          9    0.052632
# Analog cash register,Smartphone                             8    0.046784
# Security cameras,Smartphone                                 7    0.040936
# Dataphone (i.e. card payments),Security cameras...          5    0.029240
# Security cameras                                            5    0.029240
# Dataphone (i.e. card payments)                              4    0.023392
# POS system (i.e. computer + bar code scanner + ...          4    0.023392
# Dataphone (i.e. card payments),Security cameras             4    0.023392
# ...

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
filtro7_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Octava columna "5_change_store_space_last_year"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table8 = freq_tbl(tabnv["5_change_store_space_last_year"])
table8

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro8 = table8[table8["frequency"]>1]
filtro8

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro8_index = filtro8.set_index("5_change_store_space_last_year")
filtro8_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 5_change_store_space_last_year
# No cambió                             132    0.771930         0.771930
# Aumentó 25%                            13    0.076023         0.847953
# Disminuyó 15%                          11    0.064327         0.912281
# Aumentó 15%                             4    0.023392         0.935673
# Aumentó 50% o más                       4    0.023392         0.959064
# Disminuyó 25%                           4    0.023392         0.982456
# Disminuyó 50% o más                     3    0.017544         1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
filtro8_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
#alpha es la transparencia del gráfico
# Out:
# <Axes: xlabel='5_change_store_space_last_year'>

# %% [markdown]
# **Novena columna "6_change_employees_average_salary_last_year"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table9 = freq_tbl(tabnv["6_change_employees_average_salary_last_year"])
table9

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro9 = table9[table9["frequency"]>1]
filtro9

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro9_index = filtro9.set_index("6_change_employees_average_salary_last_year")
filtro9_index
# Out:
#                                              frequency  percentage  \
# 6_change_employees_average_salary_last_year
# No cambió                                           97    0.567251
# Aumentó 15%                                         23    0.134503
# Aumentó 50% o más                                   12    0.070175
# No hay empleándosela                                10    0.058480
# 40                                                   9    0.052632
# Disminuyó 15%                                        8    0.046784
# Disminuyó 25%                                        4    0.023392
# Aumentó 25%                                          4    0.023392
# 0                                                    2    0.011696
#
#                                              cumulative_perc
# 6_change_employees_average_salary_last_year
# No cambió                                           0.567251
# Aumentó 15%                                         0.701754
# ...

# %%
#realizamos gráfico de dispersión del dataframe filtrado
filtro9_index.plot("frequency", "cumulative_perc", kind = "scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Décima columna "20_reviews_finances_monthly"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table10 = freq_tbl(tabnv["20_reviews_finances_monthly"])
table10

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro10 = table10[table10["frequency"]>1]
filtro10

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro10_index = filtro10.set_index("20_reviews_finances_monthly")
filtro10_index
# Out:
#                              frequency  percentage  cumulative_perc
# 20_reviews_finances_monthly
# yes                                127     0.74269          0.74269
# no                                  44     0.25731          1.00000

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro10_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%") #esto último se refiere a un decimal
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Undécima columna "19_tax_id"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table11 = freq_tbl(tabnv["19_tax_id"])
table11

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro11 = table11[table11["frequency"]>1]
filtro11

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro11_index = filtro11.set_index("19_tax_id")
filtro11_index
# Out:
#            frequency  percentage  cumulative_perc
# 19_tax_id
# yes              123    0.719298         0.719298
# no                48    0.280702         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro11_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%") #esto último se refiere a un decimal
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Duodédicma columna "310_burnout"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table12 = freq_tbl(tabnv["310_burnout"])
table12

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro12 = table12[table12["frequency"]>1]
filtro12

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro12_index = filtro12.set_index("310_burnout")
filtro12_index
# Out:
#              frequency  percentage  cumulative_perc
# 310_burnout
# no                 107    0.625731         0.625731
# yes                 64    0.374269         1.000000

# %%
#Realizamos el gráfico de barras del dataframe filtrado
filtro12_index.plot(kind = "bar", width = 1, figsize=(10,4))
plt.title("Burnout")
plt.xlabel("Opción")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Décimo tercera columna "186_internet_connection"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table13 = freq_tbl(tabnv["186_internet_connection"])
table13

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro13 = table13[table13["frequency"]>1]
filtro13

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro13_index = filtro13.set_index("186_internet_connection")
filtro13_index
# Out:
#                          frequency  percentage  cumulative_perc
# 186_internet_connection
# yes                            114    0.666667         0.666667
# no                              57    0.333333         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro13_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%") #esto último se refiere a un decimal
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Décimo cuarta columna "189_payment_methods"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table14 = freq_tbl(tabnv["189_payment_methods"])
table14

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro14 = table14[table14["frequency"]>1]
filtro14

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro14_index = filtro14.set_index("189_payment_methods")
filtro14_index
# Out:
#                                                     frequency  percentage  \
# 189_payment_methods
# Efectivo                                                   69    0.403509
# Efectivo,Tarjeta de débito y/o crédito                     37    0.216374
# Efectivo,Tarjeta de débito y/o crédito,Transfer...         35    0.204678
# Efectivo,Transferencia interbancaria                       26    0.152047
# Aplicación móvil (e.g. CODI),Efectivo,Tarjeta d...          2    0.011696
#
#                                                     cumulative_perc
# 189_payment_methods
# Efectivo                                                   0.403509
# Efectivo,Tarjeta de débito y/o crédito                     0.619883
# Efectivo,Tarjeta de débito y/o crédito,Transfer...         0.824561
# Efectivo,Transferencia interbancaria                       0.976608
# Aplicación móvil (e.g. CODI),Efectivo,Tarjeta d...         0.988304

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
filtro14_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Décimo quinta columna "214_customer_relationship_tools"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table15 = freq_tbl(tabnv["214_customer_relationship_tools"])
table15

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro15 = table15[table15["frequency"]>1]
filtro15

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro15_index = filtro15.set_index("214_customer_relationship_tools")
filtro15_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 214_customer_relationship_tools
# Redes sociales                          45    0.263158         0.263158
# Ninguna                                 39    0.228070         0.491228
# Aplicación móvil                        36    0.210526         0.701754
# Aplicación móvil,Redes sociales         15    0.087719         0.789474
# Publicidad                              14    0.081871         0.871345
# Cuaderno                                13    0.076023         0.947368
# Teléfono                                 2    0.011696         0.959064
# Físico                                   2    0.011696         0.970760

# %%
#realizamos gráfico de dispersión del dataframe filtrado
filtro15_index.plot("frequency", "cumulative_perc", kind = "scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Décimo sexta columna "33_credit_to_customers"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table16 = freq_tbl(tabnv["33_credit_to_customers"])
table16

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro16 = table16[table16["frequency"]>1]
filtro16

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro16_index = filtro16.set_index("33_credit_to_customers")
filtro16_index
# Out:
#                         frequency  percentage  cumulative_perc
# 33_credit_to_customers
# no                            117    0.684211         0.684211
# yes                            54    0.315789         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro16_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%") #esto último se refiere a un decimal
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Décimo séptima columna "49_inventory_records"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table17 = freq_tbl(tabnv["49_inventory_records"])
table17

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro17 = table17[table17["frequency"]>1]
filtro17

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro17_index = filtro17.set_index("49_inventory_records")
filtro17_index
# Out:
#                                       frequency  percentage  cumulative_perc
# 49_inventory_records
# En papel                                     63    0.368421         0.368421
# No lo hago                                   36    0.210526         0.578947
# En Excel                                     35    0.204678         0.783626
# Software especializado + computadora         24    0.140351         0.923977
# En Excel,En papel                             7    0.040936         0.964912
# En papel,Mental                               3    0.017544         0.982456

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro17_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%") #esto último se refiere a un decimal
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Décimo octava columna "18_sales_records"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table18 = freq_tbl(tabnv["18_sales_records"])
table18

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro18 = table18[table18["frequency"]>1]
filtro18

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro18_index = filtro18.set_index("18_sales_records")
filtro18_index
# Out:
#                                                     frequency  percentage  \
# 18_sales_records
# En papel                                                   79    0.461988
# Software especializado + computadora                       25    0.146199
# No lo hago                                                 20    0.116959
# En Excel                                                   20    0.116959
# Caja registradora (análoga)                                 6    0.035088
# En Excel,En papel                                           6    0.035088
# Contadora                                                   5    0.029240
# Aplicación móvil (i.e. App) + smartphone,Softwa...          3    0.017544
#
#                                                     cumulative_perc
# 18_sales_records
# En papel                                                   0.461988
# Software especializado + computadora                       0.608187
# ...

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro18_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%") #esto último se refiere a un decimal
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Décimo novena columna "210_sales_channels"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table19 = freq_tbl(tabnv["210_sales_channels"])
table19

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro19 = table19[table19["frequency"]>1]
filtro19

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro19_index = filtro19.set_index("210_sales_channels")
filtro19_index
# Out:
#                                                     frequency  percentage  \
# 210_sales_channels
# WhatsApp                                                   26    0.152047
# Llamada a Teléfono fijo                                    19    0.111111
# Redes sociales (e.g. Facebook, Instagram),WhatsApp         17    0.099415
# Redes sociales (e.g. Facebook, Instagram)                  16    0.093567
# Llamada a Teléfono celular                                 14    0.081871
# Llamada a Teléfono celular,Redes sociales (e.g....         14    0.081871
# Llamada a Teléfono celular,WhatsApp                         8    0.046784
# conocidos paquetes cerrados                                 7    0.040936
# Página web propia                                           6    0.035088
# Llamada a Teléfono fijo,Redes sociales (e.g. Fa...          5    0.029240
# Aplicación móvil (e.g. Rappi, Uber Eats),Llamad...          3    0.017544
# ...

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
filtro19_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Vigésima columna "193_sales_planning_tools"**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table20 = freq_tbl(tabnv["193_sales_planning_tools"])
table20

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
filtro20 = table20[table20["frequency"]>1]
filtro20

# %%
#Pasamos la primera columna como índice
#Ajusto ínidice de mi dataframe
filtro20_index = filtro20.set_index("193_sales_planning_tools")
filtro20_index
# Out:
#                               frequency  percentage  cumulative_perc
# 193_sales_planning_tools
# Ninguna                              71    0.415205         0.415205
# Cuaderno                             46    0.269006         0.684211
# Excel                                17    0.099415         0.783626
# Aplicación móvil                     10    0.058480         0.842105
# Software especializado               10    0.058480         0.900585
# Cuaderno,Excel                        3    0.017544         0.918129
# Excel,Software especializado          3    0.017544         0.935673
# Cuaderno,Ninguna                      2    0.011696         0.947368

# %%
#Realizamos el gráfico de barras del dataframe filtrado
filtro20_index.plot(kind = "bar", width = 1, figsize=(10,4))
plt.title("Planning tools")
plt.xlabel("Opción")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
